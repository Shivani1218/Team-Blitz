# %% [markdown]
# # Demo Program

# %% [markdown]
# This Is A Sample Program

# %%
import matplotlib.pyplot as plt

# %%
x=[1,4,2,6,3]
y=[3,5,9,10,2]

# %%
x
# Out:
# [1, 4, 2, 6, 3]

# %%
type(x)
# Out:
# list

# %%
plt.plot(x,y,marker='.',c='r')
plt.xlabel('X-axis')
plt.ylabel('y-axis')
plt.title('line graph')
plt.show()

# %%
plt.scatter(x,y,s=100)

# %%
plt.scatter(x,y,s=100)
plt.plot(x,y,marker='.',c='r')

# %%
import numpy as np
a = np.arange(50)
b = np.random.randint(0,100,50)
c = np.random.rand(50)
plt.scatter(a,b,c=c,s=b)

# %%
people=['xx','yy','zz','aa']
weight=[50,67,87,50]
plt.bar(people,weight,width=0.5,color=['b','g','r','k'])
# Out:
# <BarContainer object of 4 artists>
